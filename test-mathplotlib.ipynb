# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(1, 20, 8)
y1 = np.random.randint(1, 12, size=8)
y2 = np.random.randint(1, 12, size=8)

plt.figure(figsize=(5, 3))
plt.plot(x1, y1, 'r-o', label="line 1")  
plt.plot(x1, y2, 'g-.o', label="line 1")  
plt.legend()
plt.show()

# %%
x3 = np.linspace(-5, 5, 100)
y4 = x3**2  
plt.figure(figsize=(5, 3))
plt.plot(x3, y4)
plt.annotate('min', xy=(0, 0), xytext=(0, 5),
             arrowprops=dict(facecolor='green', shrink=0.05))
plt.show()

# %%
vals = [24, 17, 53, 21, 35]
labels = ["Ford", "Toyota", "BMV", "AUDI", "Jaguar"]
explode = (0, 0, 0.15, 0, 0)
fig, ax = plt.subplots()
ax.pie(vals, labels=labels, explode=explode)
ax.axis("equal")
# Out:
# (-1.2497878134237272,
#  1.1071327530201776,
#  -1.1017808888721372,
#  1.1374061134115763)

# %%
vals = [24, 17, 53, 21, 35]
labels = ["Ford", "Toyota", "BMV", "AUDI", "Jaguar"]
fig, ax = plt.subplots()
ax.pie(vals, labels=labels, wedgeprops=dict(width=0.5))
# Out:
# ([<matplotlib.patches.Wedge at 0x1f1cdb191e0>,
#   <matplotlib.patches.Wedge at 0x1f1cdb1b730>,
#   <matplotlib.patches.Wedge at 0x1f1cdb1ab00>,
#   <matplotlib.patches.Wedge at 0x1f1cdb195a0>,
#   <matplotlib.patches.Wedge at 0x1f1cdb1bbb0>],
#  [Text(0.9639373540021144, 0.5299290306818474, 'Ford'),
#   Text(0.22870287165240302, 1.075962358309037, 'Toyota'),
#   Text(-1.046162158377023, 0.3399187231970734, 'BMV'),
#   Text(-0.3617533684721028, -1.0388139873909512, 'AUDI'),
#   Text(0.8174592712713289, -0.7360437078139777, 'Jaguar')])

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x*np.pi)

plt.plot(x, y, c = "r")
plt.fill_between(x, y)

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x*np.pi)
y_masked = np.ma.masked_where(y < -0.5, y)
plt.ylim(-1, 1)
plt.plot(x, y_masked, linewidth=3)

# %%
x = np.arange(0, 7)
y = x
where_set = ['pre', 'post', 'mid']
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
for i, ax in enumerate(axs):
  ax.step(x, y, "g-o", where=where_set[i])
  ax.grid()

# %%
x = np.arange(0, 11, 1)
y1 = np.array([(-0.2)*i**2+2*i for i in x])
y2 = np.array([(-0.4)*i**2+4*i for i in x])
y3 = np.array([2*i for i in x])
labels = ["y1", "y2", "y3"]
fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3, labels=labels)
ax.legend(loc='upper left')

# %%
data = np.random.randint(0, 11, (8, 8))

plt.figure(figsize=(6, 4))
plt.imshow(data, cmap='viridis', aspect='auto')
plt.colorbar()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [9, 4, 2, 4, 9]
y2 = [1, 7, 6, 3, 5]
y3 = [-7, -4, 2, -4, -7]

fg = plt.figure(figsize=(9, 4), constrained_layout=True)
gs = fg.add_gridspec(2, 2)
fig_ax_1 = fg.add_subplot(gs[0, :])
plt.plot(x, y2)
fig_ax_2 = fg.add_subplot(gs[1, 0])
plt.plot(x, y1)
fig_ax_3 = fg.add_subplot(gs[1, 1])
plt.plot(x, y3)
